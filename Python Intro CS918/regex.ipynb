# %% [markdown]
# # Regular expressions and Python

# %% [markdown]
# Regular expressions provide the programmer with a reliable and repeatable way of extracting structured information from unstructured text, this hinges on there being some sort of consistent structure for analysis within the text.
#
# In this chapter we introduce the python `re` module and try and identify a list of figures in a scientific paper and the number of times each one is mentioned.
#
# ## Regular expression language
#
# Regular expressions are used to express text in a generic way so that we can match patterns that crop up in long strings of information.
#
# We will focus on a few basic concepts:
# <table>
# <tr>
#     <th>Expression</th>
#     <th>Meaning</th>
#     <th>Examples that match</th>
#     <th>Examples that don't match</th>
# </tr>
# <tr>
# <td>[A-Z]</td>
# <td>Matches any character A-Z</td>
# <td>A, B, C</td>
# <td>a, AA, 0,</td>
# </tr>
# <tr>
# <td>[A-Z]+</td>
# <td>Matches any character A-Z 1-to-many times</td>
# <td>A,AA, AAA, AAB, ABCD, JAMES, COFFEE, SPAM</td>
# <td>a, aaa, james, coffee, Coffee or emptystring</td>
# </tr>
# <tr>
# <td>[A-Za-z]+</td>
# <td>Matches any character A-Z or a-z 1-to-many times</td>
# <td>James, Aa, Abc</td>
# <td>Test123, C O F F E E</td>
# </tr>
# <tr>
# <td>[A-Za-z0-9]+</td>
# <td>Matches any character A-Z, a-z or 0-9 1-to-many times</td>
# <td>James, Aa, Abc, Test123</td>
# <td>C O F F E E, Coffee? Coffee!</td>
# </tr>
# </table>
#
# Let's try some of these in the language

# %%
import re

def match(pattern, string):
    
    result = False
    
    match = re.match(pattern,string)
        
    if match:
        result = True
    
    print("Testing if {} will match {}. Result: {}".format(pattern,string, result))
    
    return match


match("[A-Z]", "A")
match("[A-Z]", "a")
match("[A-Z]", "0")
match("[A-Z]", "AA")
# Out:
# Testing if [A-Z] will match A. Result: True
# Testing if [A-Z] will match a. Result: False
# Testing if [A-Z] will match 0. Result: False
# Testing if [A-Z] will match AA. Result: True
# <_sre.SRE_Match object; span=(0, 1), match='A'>

# %% [markdown]
# Why does AA match against [A-Z]. Well it doesn't really. Let's examine the "substring" that python matched.

# %%
result = match("[A-Z]", "AA")

print("Matched against substring '{}'".format(result.group(0)))
# Out:
# Testing if [A-Z] will match AA. Result: True
# Matched against substring 'A'

# %% [markdown]
# So as you can see, it has matched only the first A in the string "AA". This is correct behaviour because A does belong to the string [A-Z] but we did not specify a '+' to match one-or-more so it has only returned the first instance.
#
# Let's try with [A-Z]+

# %%
match("[A-Z]+", "A")
match("[A-Z]+", "a")
match("[A-Z]+", "0")
result = match("[A-Z]+", "AA")
print("Matched against substring '{}'".format(result.group(0)))

result = match("[A-Z]+", "C O F F E E")
print("Matched against substring '{}'".format(result.group(0)))

result = match("[A-Z]+", "James")
print("Matched against substring '{}'".format(result.group(0)))
# Out:
# Testing if [A-Z]+ will match A. Result: True
# Testing if [A-Z]+ will match a. Result: False
# Testing if [A-Z]+ will match 0. Result: False
# Testing if [A-Z]+ will match AA. Result: True
# Matched against substring 'AA'
# Testing if [A-Z]+ will match C O F F E E. Result: True
# Matched against substring 'C'
# Testing if [A-Z]+ will match James. Result: True
# Matched against substring 'J'

# %% [markdown]
# This time the system matches the whole substring AA when it encounters multiple characters together. The system stumbles when it encounters 'C O F F E E'. It correctly matches the 'C' and having matched 1-to-many capital letters returns success once it encounters a space. Similarly in James it matches the capital 'J' and returns success J fulfils the requirement of 1-to-many capitals.
#
# ## More examples of regular expression grammar
#
# I'm not going to create an exhaustive list of regular expressions here. If you want to find out more about what Python supports you can [read the documentation page](https://docs.python.org/3/library/re.html#regular-expression-syntax) on regular expressions.
#
# Here are a few more examples that are useful for this exercise.
#
# <table>
# <tr>
# <th>Regular Expression</th>
# <th>Meaning</th>
# </tr>
# <tr>
# <td>.</td>
# <td>Match any non-whitespace character. That's a bit like creating a square brackets expression like [A-Za-z0-9] but also includes punctuation marks.</td>
# </tr>
# <tr>
# <td>\*</td>
# <td>Match 0-many of the preceeding pattern. For example .* would match any number of non-whitespace characters including no input at all.</td>
# </tr>
# <tr>
# <td>?</td>
# <td>Match the preceeding pattern 0-1 times. This is great for specifying that something is optional.</td>
# </tr>
# <tr>
# <td>\s</td>
# <td>Matches whitespace characters - space, tab and newline if MULTILINE patterns are enabled.</td>
# </tr>
# </table>
#
# ## Real world application.
#
# Let's find out how many figures there are in the ART corpus and how many times they are brought up. We will use our XML processing and filesystem navigation knowledge to facilitate this.
#
# ### Loading and parsing all ART corpus papers
#
# Assuming we have downloaded and extracted all papers from the CoreSC corpus to the assets folder, we can now load all of the papers and find sentences in each.

# %%
from xml.etree import ElementTree as ET
import os

def load_sentences(filename):
    
    #open and parse the paper
    tree = ET.parse(filename)
    root = tree.getroot()

    #lets find all sentences in the paper
    sentences = []
    for sentEl in root.iter("s"):
        id = sentEl.get("sid")
        text = "".join(sentEl.itertext())
        sentences.append((filename,id,text))

    return sentences


all_sentences = []
for root, dirs, files in os.walk("assets/ART_Corpus"):
    
    for file in files:
        if file.endswith(".xml"):
            all_sentences.extend( load_sentences( os.path.join(root,file )))
            
print ("Number of sentences loaded: ",len(all_sentences))
# Out:
# Number of sentences loaded:  34680

# %% [markdown]
# ### Defining a regular expression
#
# Now we are interested in finding out where the authors of these papers talk about Figures in the papers. Depending on their writing style, some authors use Figure 1, some use Fig. 1 an Some use Fig 1 (no dot). We should try and account for each of these.
#
# Sometimes figures have subfigures (i.e. Fig 1.A or 1.B) so we need to match for these too.

# %%
pattern = "Fig(ure)?.?\s+([0-9A-B]([A-Za-z0-9])*)"

print ( re.match(pattern,"Fig. 1"))
print (re.match(pattern, "Fig 1"))
print (re.match(pattern, "Figure 1"))
print (re.match(pattern, "Fig 1.A"))
# Out:
# <_sre.SRE_Match object; span=(0, 6), match='Fig. 1'>
# <_sre.SRE_Match object; span=(0, 5), match='Fig 1'>
# <_sre.SRE_Match object; span=(0, 8), match='Figure 1'>
# <_sre.SRE_Match object; span=(0, 5), match='Fig 1'>

# %% [markdown]
# You may wonder about all the extra brackets in these expressions. Parenthesis allow you to define "groups" to capture as variables and also define sub-patterns. Notice we use the brackets around 'ure' and a ? in Figure to express the fact that the ure in Figure is optional (the author might just say fig).
#
# We also put brackets around the bit of the expression that describes the figure number to allow us to capture it. Extracting this info is demonstrated below:

# %%
tests = ["Fig. 1", "Fig 1", "Figure 1", "Fig. 1.A", "Figure 2.C", "Figure. 3.2"]

for t in tests:
    m = re.match(pattern,t)
    
    if not m:
        print("Test failed for ", t)
    else:
        print ("Whole match '{}'".format( m.group(0)))
        print ("Figure or Fig?", m.group(1))
        print ("Fig ID '{}'".format(m.group(2)))
        print("--------------------")
# Out:
# Whole match 'Fig. 1'
# Figure or Fig? None
# Fig ID '1'
# --------------------
# Whole match 'Fig 1'
# Figure or Fig? None
# Fig ID '1'
# --------------------
# Whole match 'Figure 1'
# Figure or Fig? ure
# Fig ID '1'
# --------------------
# Whole match 'Fig. 1'
# Figure or Fig? None
# Fig ID '1'
# --------------------
# Whole match 'Figure 2'
# Figure or Fig? ure
# Fig ID '2'
# --------------------
# Whole match 'Figure. 3'
# Figure or Fig? ure
# Fig ID '3'
# --------------------

# %% [markdown]
# The `re.match` and `re.search` functions both return a `Match` object or `None` if the regex failed. Match objects have a group function that allows you to extract groups denoted by `()` in your expressions.
#
# Group 0 always returns the string that matched the whole expression from start to end.
#
# This pattern seems robust enough. Let's find out how many times figures are brought up in papers in the ART corpus.

# %%
from collections import Counter
from multiprocessing import Pool
from ipywidgets import FloatProgress
from IPython.display import display
from time import sleep

figs = { filename: Counter() for filename,id,text in all_sentences}
   
f = FloatProgress(min=0, max=len(all_sentences))
display(f)
    

def match_sent(sent):
    filename,id,text = sent
    sfigs = []
    
    for m in re.findall(pattern, text):
        sfigs.append(m[1])
        
        
    return filename,id,sfigs
        
    
for filename,id,sentfigs in map(match_sent, all_sentences):
    f.value += 1
    figs[filename].update(sentfigs)


for file in figs:
    print("File ", file)
    print("References to figures...: ")
    print(figs[file])
# Out:
# File  assets/ART_Corpus/ann5/b310282c_mode2.xml
# References to figures...:
# Counter({'8': 2, '2a': 2, '3': 2, '5': 1, '7': 1, '4a': 1, '1': 1, '4': 1, '2b': 1, '6': 1})
# File  assets/ART_Corpus/ann6/b315038k_mode2.xml
# References to figures...:
# Counter({'1': 1})
# File  assets/ART_Corpus/ann1/b312620j_mode2.xml
# References to figures...:
# Counter({'4': 2, '3': 2, '2b': 2, '7': 2, '1d': 1, '1c': 1, '1b': 1, '1a': 1, '2a': 1, '1': 1, '5': 1, '6': 1})
# File  assets/ART_Corpus/ann8/b413703e_mode2.xml
# References to figures...:
# Counter({'2': 3, '3a': 2, '1': 2, '4': 2, '1b': 2, '1a': 1, '3': 1, '3b': 1})
# File  assets/ART_Corpus/ann9/b502789f_mode2.xml
# References to figures...:
# Counter({'7b': 3, '8b': 2, '2': 2, '5': 2, '9b': 1, '3b': 1, '7a': 1, '3a': 1, '7d': 1, '4': 1, '10': 1, '9a': 1, '7c': 1, '11b': 1, '1': 1, '11a': 1, '6': 1, '8a': 1})
# File  assets/ART_Corpus/ann1/b403450c_mode2.xml
# References to figures...:
# Counter({'2': 3, '4': 2, '3': 1, '1a': 1, '1b': 1})
# File  assets/ART_Corpus/ann6/b404176c_mode2.xml
# References to figures...:
# Counter({'1': 2, '6': 2, '4': 1, '5': 1, '2': 1})
# File  assets/ART_Corpus/ann4/b316910c_mode2.xml
# References to figures...:
# Counter({'3': 2, '5': 1, '1': 1, '4': 1, '2': 1})
# File  assets/ART_Corpus/ann1/b310850c_mode2.xml
# References to figures...:
# Counter({'5': 6, '9': 4, '3e': 3, '3d': 3, '1': 3, '6': 3, '3c': 2, '3': 2, '4b': 2, '3b': 1, '3a': 1, '6c': 1, '8': 1, '7': 1, '2': 1, '4a': 1})
# File  assets/ART_Corpus/ann1/b403071k_mode2.xml
# References to figures...:
# Counter({'1c': 4, '1a': 3, '5b': 2, '11': 2, '3d': 2, '3b': 1, '3a': 1, '9': 1, '3c': 1, '4': 1, '3': 1, '1b': 1, '2': 1, '4a': 1, '10': 1, '5': 1, '6': 1})
# File  assets/ART_Corpus/ann1/b308195h_mode2.xml
# References to figures...:
# Counter({'1': 1, '4': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann1/b402410a_mode2.xml
# References to figures...:
# Counter({'5': 5, '3': 3, '4': 3, '2': 2, '1': 2, '6': 1})
# File  assets/ART_Corpus/ann1/b403970j_mode2.xml
# References to figures...:
# Counter({'7': 3, '5d': 3, '5c': 2, '8': 2, '4': 2, '2': 2, '5': 2, '1d': 1, '1c': 1, '3': 1, '6': 1, '1a': 1, '5a': 1, '1': 1, '6c': 1, '1b': 1})
# File  assets/ART_Corpus/ann3/b312252b_mode2.xml
# References to figures...:
# Counter({'3': 2, '2e': 1, '3b': 1, '3a': 1, '5': 1, '2b': 1, '2c': 1, '2': 1, '4a': 1, '1': 1, '10': 1, '9': 1, '6': 1})
# File  assets/ART_Corpus/ann9/b504178c_mode2.xml
# References to figures...:
# Counter({'1': 2, '3': 2, '4': 1, '2': 1})
# File  assets/ART_Corpus/ann9/b414639e_mode2.xml
# References to figures...:
# Counter({'5': 1, '1': 1, '4': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann2/b406455k_mode2.xml
# References to figures...:
# Counter({'2': 7, '5': 5, '1': 2, '3': 2, '4': 1})
# File  assets/ART_Corpus/ann6/b316211g_mode2.xml
# References to figures...:
# Counter({'10': 4, '9': 2, '2': 2, '11': 2, '3': 2, '5': 2, '6': 2, '8': 2, '7': 1, '4': 1})
# File  assets/ART_Corpus/ann5/b315893d_mode2.xml
# References to figures...:
# Counter({'6': 3, '7': 2, '2': 2, '3': 2, '4': 2, '5': 2, '10': 2, '11': 1, '1': 1})
# File  assets/ART_Corpus/ann3/b405531d_mode2.xml
# References to figures...:
# Counter({'4': 2, '5b': 2, '7a': 2, '1a': 2, '7b': 2, '5a': 2, '9': 2, '12a': 1, '6b': 1, '7d': 1, '11': 1, '5c': 1, '3': 1, '8': 1, '7c': 1, '10a': 1, '2': 1, '6a': 1, '1b': 1, '10b': 1})
# File  assets/ART_Corpus/ann8/b418708c_mode2.xml
# References to figures...:
# Counter({'2': 5, '1': 2, '3': 2, '4': 1})
# File  assets/ART_Corpus/ann7/b407358d_mode2.xml
# References to figures...:
# Counter({'3A': 1, '2A': 1, '7': 1, '9': 1, '8': 1, '1': 1, '4': 1, '5': 1, '6': 1, '3B': 1, '2B': 1})
# File  assets/ART_Corpus/ann5/b409840d_mode2.xml
# References to figures...:
# Counter({'4': 4, '2': 3, '1': 2, '3': 2})
# File  assets/ART_Corpus/ann7/b414296a_mode2.xml
# References to figures...:
# Counter({'3': 2, '2': 2, '1': 1})
# File  assets/ART_Corpus/ann6/b404604h_mode2.xml
# References to figures...:
# Counter({'7': 2, '2': 2, '1': 2, '4': 2, '5': 2, '3': 1, '6': 1})
# File  assets/ART_Corpus/ann6/b315034h_mode2.xml
# References to figures...:
# Counter({'4': 3, '1': 2, '3': 2, '5': 1, '2': 1})
# File  assets/ART_Corpus/ann4/b413539c_mode2.xml
# References to figures...:
# Counter()
# File  assets/ART_Corpus/ann2/b314609j_mode2.xml
# References to figures...:
# Counter({'1': 3, '5': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann8/b316260e_mode2.xml
# References to figures...:
# Counter()
# File  assets/ART_Corpus/ann7/b210911e_mode2.xml
# References to figures...:
# Counter({'4': 3, '1c': 2, '1a': 2, '5b': 1, '3': 1, '1b': 1, '7': 1, '2': 1, '5a': 1, '6a': 1, '5': 1, '1': 1, '6': 1})
# File  assets/ART_Corpus/ann9/b414641g_mode2.xml
# References to figures...:
# Counter({'2': 8, '1': 7, '7': 3, '3': 2, '5': 2, '8': 2, '4': 1, '6': 1})
# File  assets/ART_Corpus/ann4/b312175e_mode2.xml
# References to figures...:
# Counter({'1': 2, '3': 2, '2': 2, '4': 1})
# File  assets/ART_Corpus/ann9/b510884e_mode2.xml
# References to figures...:
# Counter({'3d': 2, '3b': 1, '3a': 1, '3c': 1, '4': 1, '3': 1, '4b': 1, '4a': 1, '2a': 1, '1': 1, '5': 1, '6': 1})
# File  assets/ART_Corpus/ann8/b419490j_mode2.xml
# References to figures...:
# Counter({'2': 2, '1': 1, '3': 1})
# File  assets/ART_Corpus/ann1/b303919f_mode2.xml
# References to figures...:
# Counter({'2A': 3, '5B': 2, '1A': 2, '4A': 1, '4': 1, '1B': 1, '5A': 1, '3': 1, '2B': 1})
# File  assets/ART_Corpus/ann1/b313883f_mode2.xml
# References to figures...:
# Counter({'1': 5, '3': 2, '1a': 1, '2': 1})
# File  assets/ART_Corpus/ann8/b313306k_mode2.xml
# References to figures...:
# Counter({'1': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann1/b313684a_mode2.xml
# References to figures...:
# Counter({'1': 3, '6': 3, '5': 2, '2a': 2, '7': 2, '4': 1, '3': 1})
# File  assets/ART_Corpus/ann9/b511334b_mode2.xml
# References to figures...:
# Counter({'2': 3, '4c': 2, '1': 2, '6a': 2, '7c': 1, '7a': 1, '6b': 1, '8': 1, '3': 1, '4b': 1, '6': 1, '7b': 1, '7': 1, '4a': 1, '5': 1})
# File  assets/ART_Corpus/ann2/b402614d_mode2.xml
# References to figures...:
# Counter({'2b': 2, '2': 2, '2a': 1, '1': 1})
# File  assets/ART_Corpus/ann9/b309070a_mode2.xml
# References to figures...:
# Counter({'6': 3, '2': 2, '3': 2, '7a': 1, '1': 1, '4': 1, '5': 1, '8': 1})
# File  assets/ART_Corpus/ann1/b405025h_mode2.xml
# References to figures...:
# Counter({'3A': 2, '2': 2, '9': 2, '3B': 2, '12': 1, '5': 1, '4': 1, '8': 1, '10': 1, '7': 1, '11b': 1, '13': 1, '1': 1, '11a': 1, '6': 1})
# File  assets/ART_Corpus/ann8/b509263a_mode2.xml
# References to figures...:
# Counter({'4i': 4, '4a': 2, '4k': 2, '3': 2, '1b': 2, '4e': 2, '4l': 1, '1a': 1, '2': 1, '2a': 1, '1c': 1})
# File  assets/ART_Corpus/ann2/b406989g_mode2.xml
# References to figures...:
# Counter({'3C': 3, '3A': 1, '2': 1, '1': 1, '3': 1, '3B': 1})
# File  assets/ART_Corpus/ann8/b404078n_mode2.xml
# References to figures...:
# Counter({'1c': 3, '3': 3, '2c': 3, '2d': 2, '4': 2, '4d': 2, '2': 2, '2b': 1, '1a': 1, '2a': 1, '5': 1, '1b': 1})
# File  assets/ART_Corpus/ann1/b403094j_mode2.xml
# References to figures...:
# Counter({'2': 2, '1b': 2, '1a': 1, '3a': 1, '5': 1, '1': 1, '4': 1, '3': 1, '6': 1})
# File  assets/ART_Corpus/ann3/b311571b_mode2.xml
# References to figures...:
# Counter({'4C': 3, '3A': 2, '1': 2, '4A': 1, '4B': 1, '2': 1, '4': 1, '3B': 1})
# File  assets/ART_Corpus/ann3/b404933k_mode2.xml
# References to figures...:
# Counter({'1': 3, '3': 2, '5b': 1, '5a': 1, '2a': 1, '2b': 1})
# File  assets/ART_Corpus/ann6/b404889j_mode2.xml
# References to figures...:
# Counter({'6': 5, '2': 4, '3': 3, '4': 3, '7': 2, '1': 2, '5': 2, '8': 1})
# File  assets/ART_Corpus/ann4/b313987e_mode2.xml
# References to figures...:
# Counter({'2': 4, '3b': 1, '3a': 1, '5a': 1, '1': 1, '4': 1, '5b': 1})
# File  assets/ART_Corpus/ann6/b310952f_mode2.xml
# References to figures...:
# Counter({'1': 2, '4': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann6/b315626p_mode2.xml
# References to figures...:
# Counter({'1': 3, '9': 3, '11': 2, '4': 2, '3': 2, '8': 2, '2': 2, '12': 1, '16': 1, '5': 1, '10': 1, '7': 1, '15': 1, '6': 1})
# File  assets/ART_Corpus/ann4/b411047a_mode2.xml
# References to figures...:
# Counter({'2': 5, '3': 4, '7': 2, '4': 2, '6': 2, '1': 1, '5': 1})
# File  assets/ART_Corpus/ann7/b305156k_mode2.xml
# References to figures...:
# Counter({'12': 2, '5': 2, '11': 2, '4': 2, '3': 2, '7': 2, '8': 2, '1': 2, '6': 2, '10': 1, '2': 1, '9': 1})
# File  assets/ART_Corpus/ann4/b404633a_mode2.xml
# References to figures...:
# Counter({'2c': 2, '1c': 2, '3a': 2, '3b': 1, '4': 1, '1a': 1, '2a': 1, '1': 1, '5': 1, '1b': 1, '2b': 1})
# File  assets/ART_Corpus/ann7/b405149a_mode2.xml
# References to figures...:
# Counter({'1': 2, '2': 2, '5': 1, '4': 1, '3': 1})
# File  assets/ART_Corpus/ann9/b415247f_mode2.xml
# References to figures...:
# Counter({'1': 3, '5': 3, '5b': 1, '2': 1, '3': 1, '4': 1, '6': 1})
# File  assets/ART_Corpus/ann8/b409258a_mode2.xml
# References to figures...:
# Counter({'5': 7, '6': 6, '2a': 3, '8': 2, '1c': 2, '3': 2, '2b': 2, '1a': 2, '1d': 1, '2d': 1, '1e': 1, '4': 1, '2c': 1, '7': 1, '2': 1, '4a': 1, '1b': 1})
# File  assets/ART_Corpus/ann1/b315019d_mode2.xml
# References to figures...:
# Counter({'1': 2})
# File  assets/ART_Corpus/ann2/b308202d_mode2.xml
# References to figures...:
# Counter({'1': 11, '3': 5, '2': 4, '4': 4, '7': 3, '10': 3, '6': 3, '8': 3, '9': 2, '5': 1})
# File  assets/ART_Corpus/ann9/b312724a_mode2.xml
# References to figures...:
# Counter()
# File  assets/ART_Corpus/ann4/b411082j_mode2.xml
# References to figures...:
# Counter({'1': 4, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann8/b511710k_mode2.xml
# References to figures...:
# Counter({'2': 4, '1': 1, '3': 1})
# File  assets/ART_Corpus/ann8/b310851a_mode2.xml
# References to figures...:
# Counter({'1': 2, '3': 2})
# File  assets/ART_Corpus/ann8/b405013d_mode2.xml
# References to figures...:
# Counter({'1': 10, '3': 3, '2a': 1, '2b': 1})
# File  assets/ART_Corpus/ann5/b406795a_mode2.xml
# References to figures...:
# Counter({'3': 7, '1': 5, '5': 3, '2': 3, '5b': 1, '5a': 1, '2a': 1, '4': 1, '2b': 1, '2c': 1})
# File  assets/ART_Corpus/ann5/b306702e_mode2.xml
# References to figures...:
# Counter({'4': 6, '2': 3, '1': 2, '5': 2, '3': 1, '6': 1})
# File  assets/ART_Corpus/ann5/b314263a_mode2.xml
# References to figures...:
# Counter({'3': 3, '2': 3, '1': 1})
# File  assets/ART_Corpus/ann1/b400471j_mode2.xml
# References to figures...:
# Counter({'18': 4, '17': 1, '7': 1, '2': 1, '3': 1, '1': 1, '4': 1, '5': 1, '6': 1})
# File  assets/ART_Corpus/ann5/b411001c_mode2.xml
# References to figures...:
# Counter({'2': 3, '5': 2, '6': 2, '7': 1, '1a': 1, '3': 1, '4': 1})
# File  assets/ART_Corpus/ann3/b305411j_mode2.xml
# References to figures...:
# Counter({'2': 3, '3': 2, '5': 1, '1': 1, '4': 1})
# File  assets/ART_Corpus/ann9/b313922k_mode2.xml
# References to figures...:
# Counter({'22': 5, '3': 5, '5': 4, '4': 3, '1': 3, '6': 3, '2': 2, '20': 1})
# File  assets/ART_Corpus/ann9/b508229c_mode2.xml
# References to figures...:
# Counter({'3': 5, '2': 3, '5a': 3, '1a': 2, '4a': 2, '1': 2, '5': 1, '1b': 1, '4b': 1, '5b': 1})
# File  assets/ART_Corpus/ann6/b316053j_mode2.xml
# References to figures...:
# Counter({'1': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann4/b315520j_mode2.xml
# References to figures...:
# Counter({'7': 4, '9': 2, '8': 2, '10': 2, '2': 1, '1': 1, '3': 1, '6': 1})
# File  assets/ART_Corpus/ann8/b314521m_mode2.xml
# References to figures...:
# Counter({'3': 7, '1': 3, '5': 1, '4': 1, '2': 1})
# File  assets/ART_Corpus/ann3/b400243a_mode2.xml
# References to figures...:
# Counter({'4': 3, '1': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann2/b411757c_mode2.xml
# References to figures...:
# Counter({'5': 5, '2': 4, '4': 2, '7': 1, '3': 1, '1': 1, '6': 1})
# File  assets/ART_Corpus/ann7/b411989d_mode2.xml
# References to figures...:
# Counter({'3': 2, '5': 1, '1': 1, '4': 1, '2': 1})
# File  assets/ART_Corpus/ann4/b312562a_mode2.xml
# References to figures...:
# Counter({'2': 9, '3': 2, '1a': 2, '4c': 1, '1': 1, '3b': 1, '3a': 1, '1c': 1, '4': 1, '6': 1})
# File  assets/ART_Corpus/ann3/b314333n_mode2.xml
# References to figures...:
# Counter({'1': 5, '3': 3, '9': 1, '7': 1, '2': 1, '5': 1, '6': 1, '8': 1})
# File  assets/ART_Corpus/ann7/b410283e_mode2.xml
# References to figures...:
# Counter({'1': 1, '3d': 1, '2c': 1, '3a': 1})
# File  assets/ART_Corpus/ann4/b316514k_mode2.xml
# References to figures...:
# Counter({'1': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann9/b508092d_mode2.xml
# References to figures...:
# Counter({'7': 4, '5': 4, '1': 4, '4': 4, '3': 3, '9': 2, '2': 2, '8': 2, '10': 1, '11': 1, '6': 1})
# File  assets/ART_Corpus/ann5/b407082h_mode2.xml
# References to figures...:
# Counter({'2': 4, '1': 3})
# File  assets/ART_Corpus/ann2/b309964d_mode2.xml
# References to figures...:
# Counter({'2': 3, '1': 1, '4': 1, '3': 1})
# File  assets/ART_Corpus/ann8/b414986f_mode2.xml
# References to figures...:
# Counter({'2': 2, '3': 1, '5': 1, '1': 1, '1a': 1, '2a': 1, '1c': 1, '4': 1, '2b': 1, '2c': 1, '1b': 1})
# File  assets/ART_Corpus/ann4/b312242e_mode2.xml
# References to figures...:
# Counter({'1a': 2, '1c': 2, '3': 2, '1b': 2, '3b': 2, '2': 1, '3a': 1, '4': 1})
# File  assets/ART_Corpus/ann1/b306684c_mode2.xml
# References to figures...:
# Counter({'1': 2, '3': 2, '4': 1, '2': 1})
# File  assets/ART_Corpus/ann7/b403127j_mode2.xml
# References to figures...:
# Counter({'2': 3, '5': 2, '3': 2, '3C': 1, '4C': 1, '1': 1, '4': 1, '3B': 1})
# File  assets/ART_Corpus/ann3/b411335g_mode2.xml
# References to figures...:
# Counter({'1': 4, '2': 3, '1a': 2, '1c': 1, '1b': 1})
# File  assets/ART_Corpus/ann4/b403191c_mode2.xml
# References to figures...:
# Counter({'10': 7, '2a': 3, '3': 2, '2': 2, '6a': 2, '6b': 1, '8': 1, '2b': 1, '6c': 1, '9': 1, '7': 1, '2c': 1, '4a': 1, '5': 1, '1': 1})
# File  assets/ART_Corpus/ann2/b400402g_mode2.xml
# References to figures...:
# Counter({'1': 2, '4': 2, '2': 2, '3': 1})
# File  assets/ART_Corpus/ann4/b408777a_mode2.xml
# References to figures...:
# Counter({'3': 6, '2a': 3, '4': 2, '2b': 2, '1a': 1, '1b': 1})
# File  assets/ART_Corpus/ann1/b402989p_mode2.xml
# References to figures...:
# Counter({'2': 3, '1': 2, '3': 1})
# File  assets/ART_Corpus/ann9/b403032j_mode2.xml
# References to figures...:
# Counter({'1': 2, '4': 2, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann3/b411356j_mode2.xml
# References to figures...:
# Counter({'1': 8, '3': 2, '2A': 1, '5': 1, '4': 1, '6': 1, '2B': 1})
# File  assets/ART_Corpus/ann4/b312859h_mode2.xml
# References to figures...:
# Counter({'1': 4, '5': 3, '6': 2, '2': 1, '3': 1, '4': 1})
# File  assets/ART_Corpus/ann6/b413672a_mode2.xml
# References to figures...:
# Counter({'1': 2, '3': 2, '2': 1})
# File  assets/ART_Corpus/ann1/b409641j_mode2.xml
# References to figures...:
# Counter({'2': 3, '1': 2})
# File  assets/ART_Corpus/ann6/b303117a_mode2.xml
# References to figures...:
# Counter({'5': 2, '2': 2, '4': 2, '8': 2, '6': 2, '6B': 1, '3': 1, '1': 1, '6A': 1, '7': 1})
# File  assets/ART_Corpus/ann6/b411798k_mode2.xml
# References to figures...:
# Counter({'6': 4, '2': 2, '3': 2, '7': 1, '1': 1, '4': 1, '5': 1, '8': 1})
# File  assets/ART_Corpus/ann5/b313691d_mode2.xml
# References to figures...:
# Counter({'5': 5, '2': 4, '6': 4, '4': 3, '6b': 1, '6a': 1})
# File  assets/ART_Corpus/ann3/b409443c_mode2.xml
# References to figures...:
# Counter({'5': 4, '6': 3, '4': 2, '8': 2, '13': 2, '9': 2, '11': 1, '14': 1, '10': 1, '7': 1, '12': 1, '1': 1})
# File  assets/ART_Corpus/ann5/b311582h_mode2.xml
# References to figures...:
# Counter({'1': 12, '2': 6, '9': 5, '5': 5, '7': 4, '6': 4, '8': 4, '3': 3, '4': 2})
# File  assets/ART_Corpus/ann1/b409589h_mode2.xml
# References to figures...:
# Counter({'5': 5, '3': 2, '4c': 1, '3b': 1, '2': 1, '3a': 1, '4a': 1, '4d': 1, '1b': 1, '4b': 1, '1a': 1})
# File  assets/ART_Corpus/ann3/b406569g_mode2.xml
# References to figures...:
# Counter({'3': 10, '4': 6, '5': 2, '2': 2, '1': 1})
# File  assets/ART_Corpus/ann5/b402623c_mode2.xml
# References to figures...:
# Counter({'10': 3, '17': 2, '6b': 2, '5': 2, '7': 2, '9': 2, '12': 1, '16': 1, '19': 1, '11': 1, '4': 1, '3': 1, '14': 1, '8': 1, '2': 1, '15': 1, '13': 1, '1': 1, '18': 1, '6a': 1})
# File  assets/ART_Corpus/ann5/b404880f_mode2.xml
# References to figures...:
# Counter({'2a': 2, '1': 2, '2d': 1, '2b': 1, '2c': 1})
# File  assets/ART_Corpus/ann8/b509164k_mode2.xml
# References to figures...:
# Counter({'6': 4, '2': 3, '1': 3, '4': 3, '5': 2, '3': 1, '1b': 1})
# File  assets/ART_Corpus/ann6/b314882c_mode2.xml
# References to figures...:
# Counter({'3': 2, '1a': 1, '2': 1, '1': 1, '1b': 1, '6': 1})
# File  assets/ART_Corpus/ann5/b408415b_mode2.xml
# References to figures...:
# Counter({'2': 2, '1': 1})
# File  assets/ART_Corpus/ann2/b411500g_mode2.xml
# References to figures...:
# Counter({'1': 2})
# File  assets/ART_Corpus/ann7/b410112j_mode2.xml
# References to figures...:
# Counter({'1': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann3/b301675g_mode2.xml
# References to figures...:
# Counter()
# File  assets/ART_Corpus/ann8/b316895f_mode2.xml
# References to figures...:
# Counter({'3': 3, '14': 3, '17': 2, '16': 2, '6b': 2, '5': 2, '4': 2, '2': 2, '15': 2, '13': 2, '1': 2, '18': 2, '6a': 2, '12': 1, '11': 1, '10': 1, '7': 1, '8': 1, '9': 1})
# File  assets/ART_Corpus/ann9/b415563f_mode2.xml
# References to figures...:
# Counter({'1': 4, '4': 4, '2': 3, '3': 2, '5': 1})
# File  assets/ART_Corpus/ann7/b310932a_mode2.xml
# References to figures...:
# Counter({'1': 2, '2': 2, '3': 1})
# File  assets/ART_Corpus/ann2/b313399k_mode2.xml
# References to figures...:
# Counter({'1': 3, '2': 2})
# File  assets/ART_Corpus/ann4/b404146a_mode2.xml
# References to figures...:
# Counter({'2': 4, '1': 2, '3': 1})
# File  assets/ART_Corpus/ann6/b406051b_mode2.xml
# References to figures...:
# Counter({'4': 4, '3': 4, '9': 4, '5': 3, '2': 2, '10': 2, '11a': 1, '3b': 1, '3a': 1, '8': 1, '7': 1, '11b': 1, '13': 1, '1': 1, '6': 1})
# File  assets/ART_Corpus/ann1/b313220j_mode2.xml
# References to figures...:
# Counter({'1': 3, '11': 2, '4': 2, '10': 2, '7': 2, '8': 2, '9': 2, '17': 1, '12': 1, '16': 1, '5': 1, '3': 1, '14': 1, '2': 1, '15': 1, '13': 1, '6': 1})
# File  assets/ART_Corpus/ann3/b316185d_mode2.xml
# References to figures...:
# Counter({'7a': 3, '2b': 3, '2a': 3, '4': 2, '4a': 2, '6': 2, '4c': 1, '3': 1, '8': 1, '9a': 1, '9': 1, '9c': 1, '1': 1, '5': 1})
# File  assets/ART_Corpus/ann9/b407279k_mode2.xml
# References to figures...:
# Counter({'3': 4, '5': 4, '6': 3, '8': 3, '7': 1, '2': 1, '1': 1, '4': 1})
# File  assets/ART_Corpus/ann7/b407728h_mode2.xml
# References to figures...:
# Counter({'2': 5, '1': 3, '4': 3, '7': 2, '3': 1, '5': 1, '6': 1})
# File  assets/ART_Corpus/ann5/b410053k_mode2.xml
# References to figures...:
# Counter({'2': 2, '5': 2, '4': 2, '3b': 1, '3a': 1, '1': 1, '3': 1, '2c': 1, '6': 1})
# File  assets/ART_Corpus/ann2/b412680g_mode2.xml
# References to figures...:
# Counter({'2A': 3, '6': 2, '2B': 2, '2': 1, '5': 1, '1': 1, '4': 1, '3': 1})
# File  assets/ART_Corpus/ann9/b504407c_mode2.xml
# References to figures...:
# Counter({'1': 4, '6': 3, '8B': 2, '8': 2, '4': 2, '5A': 2, '9A': 1, '7A': 1, '9C': 1, '3': 1, '4B': 1, '2': 1, '9B': 1, '8A': 1, '7B': 1})
# File  assets/ART_Corpus/ann6/b410120k_mode2.xml
# References to figures...:
# Counter({'1': 1})
# File  assets/ART_Corpus/ann5/b410439k_mode2.xml
# References to figures...:
# Counter({'2e': 1, '2a': 1, '1': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann7/b314644h_mode2.xml
# References to figures...:
# Counter({'2b': 7, '4': 4, '3b': 3, '5': 3, '1': 3, '6': 3, '7': 2, '2': 2, '3': 2, '1a': 1, '3d': 1})
# File  assets/ART_Corpus/ann8/b313717a_mode2.xml
# References to figures...:
# Counter({'5': 7, '7': 7, '4': 5, '6': 5, '3': 2})
# File  assets/ART_Corpus/ann3/b314172a_mode2.xml
# References to figures...:
# Counter({'3b': 1, '3a': 1, '6b': 1, '8': 1, '2b': 1, '4b': 1, '6': 1, '5a': 1, '4a': 1, '2a': 1, '6a': 1, '1': 1, '5b': 1})
# File  assets/ART_Corpus/ann4/b415321a_mode2.xml
# References to figures...:
# Counter({'1': 2, '4': 2, '3': 2, '5': 1, '2': 1})
# File  assets/ART_Corpus/ann7/b413535k_mode2.xml
# References to figures...:
# Counter({'7': 3, '12': 2, '19': 2, '11': 2, '2': 2, '13': 2, '6': 2, '17': 1, '20a': 1, '20b': 1, '5b': 1, '4': 1, '3': 1, '15': 1, '1': 1, '20': 1, '18b': 1, '16': 1, '18a': 1, '10a': 1, '9b': 1, '9': 1, '8': 1, '14': 1, '10b': 1, '5': 1})
# File  assets/ART_Corpus/ann2/b313781c_mode2.xml
# References to figures...:
# Counter({'4': 2, '6': 2, '5': 1, '3': 1})
# File  assets/ART_Corpus/ann4/b310825b_mode2.xml
# References to figures...:
# Counter({'1': 2, '4': 2, '6a': 1, '2': 1, '5': 1, '3': 1, '2b': 1})
# File  assets/ART_Corpus/ann1/b410905h_mode2.xml
# References to figures...:
# Counter({'6': 4, '5': 2, '2': 1, '3': 1, '1': 1, '4': 1})
# File  assets/ART_Corpus/ann8/b312115a_mode2.xml
# References to figures...:
# Counter({'4': 3, '9': 3, '12': 2, '3': 2, '10': 2, '7': 2, '1': 2, '6': 2, '5': 1, '11': 1, '8': 1, '2': 1})
# File  assets/ART_Corpus/ann1/b414459g_mode2.xml
# References to figures...:
# Counter({'1': 3, '5': 2, '4': 2, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann3/b402163k_mode2.xml
# References to figures...:
# Counter({'4': 2, '7': 1, '2': 1, '1': 1, '3': 1, '6': 1})
# File  assets/ART_Corpus/ann7/b309357n_mode2.xml
# References to figures...:
# Counter({'5': 4, '1': 3, '3f': 2, '3': 2, '3b': 1, '3a': 1, '3c': 1, '4': 1, '3e': 1, '3d': 1, '2': 1, '6': 1})
# File  assets/ART_Corpus/ann4/b312684f_mode2.xml
# References to figures...:
# Counter({'1': 4, '1B1': 3, '2': 3, '2A': 1, '1B': 1, '1A2': 1, '2b': 1, '2B': 1})
# File  assets/ART_Corpus/ann7/b316385g_mode2.xml
# References to figures...:
# Counter({'1': 1, '4': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann2/b313110f_mode2.xml
# References to figures...:
# Counter({'1': 15, '4': 3, '9': 1, '7': 1, '2': 1, '3': 1, '5': 1, '6': 1, '8': 1})
# File  assets/ART_Corpus/ann7/b406562j_mode2.xml
# References to figures...:
# Counter({'1': 2})
# File  assets/ART_Corpus/ann8/b314070a_mode2.xml
# References to figures...:
# Counter({'1': 2, '2': 2})
# File  assets/ART_Corpus/ann5/b312040f_mode2.xml
# References to figures...:
# Counter({'8': 2, '7': 1, '2': 1, '3': 1, '1': 1, '4': 1, '5': 1, '6': 1})
# File  assets/ART_Corpus/ann8/b506075c_mode2.xml
# References to figures...:
# Counter({'4': 12, '3': 11, '2': 6, '6': 6, '8': 5, '5': 4, '7': 2, '1': 2})
# File  assets/ART_Corpus/ann6/b211806h_mode2.xml
# References to figures...:
# Counter({'1': 6, '3': 6, '2': 2, '4': 1})
# File  assets/ART_Corpus/ann1/b409366f_mode2.xml
# References to figures...:
# Counter({'2': 4, '5': 3, '1': 2, '3': 2, '4': 1})
# File  assets/ART_Corpus/ann3/b316144g_mode2.xml
# References to figures...:
# Counter({'11': 3, '6b': 2, '7': 1, '3b': 1, '3a': 1, '8': 1, '4': 1, '5': 1, '10': 1})
# File  assets/ART_Corpus/ann3/b315777f_mode2.xml
# References to figures...:
# Counter({'1': 2, '5': 2, '6': 2, '7': 1, '2': 1, '3': 1, '4': 1})
# File  assets/ART_Corpus/ann8/b411044g_mode2.xml
# References to figures...:
# Counter({'4': 4, '3': 2, '1': 2, '2': 1, '5': 1, '6': 1})
# File  assets/ART_Corpus/ann9/b316166h_mode2.xml
# References to figures...:
# Counter({'1': 4, '2': 3})
# File  assets/ART_Corpus/ann6/b306787b_mode2.xml
# References to figures...:
# Counter({'5': 2, '2': 1, '3': 1, '1': 1, '4': 1, '6': 1})
# File  assets/ART_Corpus/ann5/b312984e_mode2.xml
# References to figures...:
# Counter({'5': 1, '1': 1, '4': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann4/b313474a_mode2.xml
# References to figures...:
# Counter({'4': 5, '5': 3, '8': 3, '11': 2, '3': 2, '7': 2, '2': 2, '6': 2, '12': 1, '10': 1, '13': 1, '1': 1, '9': 1})
# File  assets/ART_Corpus/ann5/b313313n_mode2.xml
# References to figures...:
# Counter({'1': 3, '5': 3, '6d': 3, '6a': 2, '7': 2, '6b': 2, '6': 2, '2': 1, '3': 1, '4': 1, '6c': 1})
# File  assets/ART_Corpus/ann8/b412883d_mode2.xml
# References to figures...:
# Counter({'1': 2, '2': 1})
# File  assets/ART_Corpus/ann6/b407512a_mode2.xml
# References to figures...:
# Counter({'2': 2, '1': 1})
# File  assets/ART_Corpus/ann6/b308201f_mode2.xml
# References to figures...:
# Counter({'5': 7, '7': 6, '10': 5, '2': 4, '3': 4, '4': 3, '9': 2, '1': 2, '6': 2, '8': 2})
# File  assets/ART_Corpus/ann9/b508281a_mode2.xml
# References to figures...:
# Counter({'3': 3, '7': 3, '4': 2, '2': 2, '1': 2, '5': 1, '11': 1, '8': 1, '2b': 1, '10': 1, '7b': 1, '2a': 1, '9': 1, '6': 1})
# File  assets/ART_Corpus/ann6/b407283a_mode2.xml
# References to figures...:
# Counter({'1': 3, '2': 3})
# File  assets/ART_Corpus/ann7/b408506j_mode2.xml
# References to figures...:
# Counter({'6': 5, '4': 3, '5': 3, '8': 3, '7': 2, '2': 2, '3': 1, '1': 1})
# File  assets/ART_Corpus/ann8/b419201j_mode2.xml
# References to figures...:
# Counter({'2': 4, '1': 1, '4': 1, '5': 1})
# File  assets/ART_Corpus/ann3/b312196h_mode2.xml
# References to figures...:
# Counter({'1B': 2, '1C': 2, '3': 2, '3A': 1, '2A': 1, '4B': 1, '2': 1, '2B': 1, '4A': 1, '3B': 1, '1A': 1})
# File  assets/ART_Corpus/ann1/b402496f_mode2.xml
# References to figures...:
# Counter({'3b': 3, '4a': 3, '2': 2, '5': 1, '1': 1, '3': 1})
# File  assets/ART_Corpus/ann2/b401234h_mode2.xml
# References to figures...:
# Counter({'1c': 4, '1d': 2, '1b': 2, '5': 2, '3b': 1, '3a': 1, '9': 1, '6b': 1, '8': 1, '8e': 1, '4b': 1, '6a': 1, '7': 1, '2': 1, '4a': 1, '1': 1, '10': 1, '6': 1})
# File  assets/ART_Corpus/ann8/b407297a_mode2.xml
# References to figures...:
# Counter({'7': 2, '5': 1, '4': 1, '3': 1, '6': 1})
# File  assets/ART_Corpus/ann7/b315089e_mode2.xml
# References to figures...:
# Counter({'1': 3, '4a': 2, '3': 1, '4b': 1, '2': 1})
# File  assets/ART_Corpus/ann9/b315394k_mode2.xml
# References to figures...:
# Counter({'2': 5, '1a': 2, '3': 2, '1b': 2, '3a': 1, '1': 1, '3b': 1})
# File  assets/ART_Corpus/ann9/b413603a_mode2.xml
# References to figures...:
# Counter({'6': 7, '11': 4, '4': 4, '1': 4, '12': 2, '3': 2, '14': 2, '10': 2, '7': 2, '13': 2, '9': 2, '5': 1, '8': 1, '2': 1, '13a': 1})
# File  assets/ART_Corpus/ann3/b310865a_mode2.xml
# References to figures...:
# Counter({'3': 7, '5': 4, '7': 3, '4': 2, '6': 2, '8': 2, '2': 1, '1': 1})
# File  assets/ART_Corpus/ann7/b302761a_mode2.xml
# References to figures...:
# Counter({'2': 7, '1': 1, '3': 1})
# File  assets/ART_Corpus/ann4/b304938h_mode2.xml
# References to figures...:
# Counter({'1': 2, '4A': 1, '4': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann7/b313251j_mode2.xml
# References to figures...:
# Counter({'1': 4, '5': 3, '4': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann7/b315695h_mode2.xml
# References to figures...:
# Counter({'1': 3, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann8/b403898c_mode2.xml
# References to figures...:
# Counter({'1a': 2, '2': 2, '1c': 1, '1': 1, '1b': 1})
# File  assets/ART_Corpus/ann3/b304943d_mode2.xml
# References to figures...:
# Counter({'3B': 3, '1B': 1, '4B': 1, '5': 1, '2B': 1})
# File  assets/ART_Corpus/ann6/b314764a_mode2.xml
# References to figures...:
# Counter({'2': 2, '5a': 2, '5c': 1, '7': 1, '5b': 1, '3a': 1, '1': 1, '4': 1, '8': 1, '6a': 1})
# File  assets/ART_Corpus/ann9/b501029b_mode2.xml
# References to figures...:
# Counter({'2': 3, '1': 1})
# File  assets/ART_Corpus/ann5/b407174c_mode2.xml
# References to figures...:
# Counter({'1': 11, '4': 3, '5': 2, '2a': 2, '2b': 2, '3': 1})
# File  assets/ART_Corpus/ann3/b412414f_mode2.xml
# References to figures...:
# Counter({'1': 4, '5b': 3, '5a': 3, '5c': 2, '7': 2, '2': 2, '3': 1, '4': 1, '5': 1, '6': 1, '8': 1})
# File  assets/ART_Corpus/ann5/b401299b_mode2.xml
# References to figures...:
# Counter({'3A': 2, '2A': 2, '4': 2, '5A': 1, '5B': 1, '5': 1, '1': 1, '3': 1, '3B': 1, '2B': 1})
# File  assets/ART_Corpus/ann5/b403534h_mode2.xml
# References to figures...:
# Counter({'1': 1, '4': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann4/b315071b_mode2.xml
# References to figures...:
# Counter({'1': 3, '3': 2, '4': 2, '2b': 2, '5': 2, '7a': 1, '3a': 1, '8': 1, '9': 1, '7b': 1, '2a': 1, '6': 1})
# File  assets/ART_Corpus/ann5/b405233a_mode2.xml
# References to figures...:
# Counter({'7': 1, '3C': 1, '2': 1, '1B': 1, '1C': 1, '4': 1, '3': 1, '6': 1, '5': 1, '1A': 1})
# File  assets/ART_Corpus/ann2/b315069k_mode2.xml
# References to figures...:
# Counter({'7': 1, '2': 1, '3': 1, '1': 1, '4': 1, '5': 1, '6': 1, '8': 1})
# File  assets/ART_Corpus/ann4/b408850f_mode2.xml
# References to figures...:
# Counter({'1': 1, '4': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann7/b316402k_mode2.xml
# References to figures...:
# Counter({'7': 2, '3': 2, '2': 1, '1': 1, '4': 1, '5': 1, '6': 1})
# File  assets/ART_Corpus/ann9/b506280b_mode2.xml
# References to figures...:
# Counter({'4a': 3, '6': 3, '1a': 2, '2': 2, '3': 2, '4c': 1, '7': 1, '5': 1, '1': 1, '4b': 1})
# File  assets/ART_Corpus/ann4/b411977k_mode2.xml
# References to figures...:
# Counter({'8a': 2, '2e': 1, '8b': 1, '10a': 1, '9b': 1, '4': 1, '3': 1, '2c': 1, '2b': 1, '9a': 1, '7': 1, '10b': 1, '2': 1, '1': 1})
# File  assets/ART_Corpus/ann2/b400183d_mode2.xml
# References to figures...:
# Counter({'1': 5, '4': 5, '5': 4, '8': 1})
# File  assets/ART_Corpus/ann2/b305670h_mode2.xml
# References to figures...:
# Counter({'2a': 1, '1': 1})
# File  assets/ART_Corpus/ann6/b410922h_mode2.xml
# References to figures...:
# Counter({'1': 7, '2': 3, '4': 3, '3': 2, '5': 2, '6': 2})
# File  assets/ART_Corpus/ann3/b314320a_mode2.xml
# References to figures...:
# Counter({'2': 6, '1': 3, '3': 1})
# File  assets/ART_Corpus/ann2/b411005f_mode2.xml
# References to figures...:
# Counter({'1': 3, '3': 2, '4': 1, '2': 1})
# File  assets/ART_Corpus/ann1/b316620a_mode2.xml
# References to figures...:
# Counter({'1': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann2/b405211k_mode2.xml
# References to figures...:
# Counter({'3': 2, '1': 1, '4': 1, '2': 1})
# File  assets/ART_Corpus/ann5/b409686j_mode2.xml
# References to figures...:
# Counter({'2A': 2, '1C': 2, '2B': 2, '1B': 1, '1A': 1})
# File  assets/ART_Corpus/ann2/b404632c_mode2.xml
# References to figures...:
# Counter({'14': 2, '9': 2, '19': 1, '8': 1, '11': 1, '4': 1, '3': 1, '10': 1, '12': 1, '2': 1, '18': 1, '13': 1, '1': 1, '20': 1})
# File  assets/ART_Corpus/ann2/b313354k_mode2.xml
# References to figures...:
# Counter({'1': 2, '2': 2, '3': 1})
# File  assets/ART_Corpus/ann3/b407316a_mode2.xml
# References to figures...:
# Counter({'1': 2, '4': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann9/b416924g_mode2.xml
# References to figures...:
# Counter({'1': 1, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann2/b315252a_mode2.xml
# References to figures...:
# Counter({'1': 4, '5': 3, '8': 2, '3': 2, '10': 2, '4': 1, '5b': 1, '5c': 1, '3c': 1, '3a': 1, '9': 1, '7': 1, '2': 1, '11': 1, '5a': 1, '6': 1})
# File  assets/ART_Corpus/ann6/b314692h_mode2.xml
# References to figures...:
# Counter({'9': 1, '7': 1, '2': 1, '3': 1, '1': 1, '4': 1, '5': 1, '6': 1, '8': 1})
# File  assets/ART_Corpus/ann2/b313362a_mode2.xml
# References to figures...:
# Counter({'1': 2, '3': 1, '2': 1})
# File  assets/ART_Corpus/ann6/b406695b_mode2.xml
# References to figures...:
# Counter({'3': 2, '1': 1, '4': 1, '2': 1})
# File  assets/ART_Corpus/ann4/b209460f_mode2.xml
# References to figures...:
# Counter({'1': 3, '2': 1})
# File  assets/ART_Corpus/ann8/b314189f_mode2.xml
# References to figures...:
# Counter({'1': 6, '2': 3, '3': 2, '6': 2, '9': 1, '7': 1, '4': 1, '5': 1, '8': 1})
# File  assets/ART_Corpus/ann3/b314477a_mode2.xml
# References to figures...:
# Counter({'3': 3, '2': 3, '1': 1, '4': 1})
# File  assets/ART_Corpus/ann4/b406899h_mode2.xml
# References to figures...:
# Counter({'1': 2, '4': 2, '3': 2, '5': 1, '2': 1})
# File  assets/ART_Corpus/ann7/b407500e_mode2.xml
# References to figures...:
# Counter({'4': 4, '3': 4, '1': 3, '2': 3})
# File  assets/ART_Corpus/ann3/b402202e_mode2.xml
# References to figures...:
# Counter({'1': 4, '3': 2, '2': 1})
# File  assets/ART_Corpus/ann9/b405543h_mode2.xml
# References to figures...:
# Counter({'7': 3, '4': 2, '1': 2, '5': 2, '6': 2, '5b': 1, '3a': 1, '3': 1, '4b': 1, '2': 1, '4a': 1, '5a': 1})
# File  assets/ART_Corpus/ann2/b312189e_mode2.xml
# References to figures...:
# Counter({'4': 5, '5': 4, '6': 2, '7': 1, '2': 1, '3': 1, '1': 1})
# File  assets/ART_Corpus/ann7/b405115g_mode2.xml
# References to figures...:
# Counter({'1': 2, '2': 1})
# File  assets/ART_Corpus/ann6/b314077f_mode2.xml
# References to figures...:
# Counter({'3b': 2, '3e': 1, '3a': 1, '4a': 1, '2a': 1, '1': 1, '3c': 1, '2b': 1, '4b': 1, '3d': 1})
# File  assets/ART_Corpus/ann2/b313261g_mode2.xml
# References to figures...:
# Counter({'4': 3, '2': 2, '5': 1, '1': 1, '3': 1})
# File  assets/ART_Corpus/ann1/b304116f_mode2.xml
# References to figures...:
# Counter({'5': 4, '2c': 3, '10': 3, '3': 2, '4': 2, '2b': 2, '9': 2, '6': 2, '2d': 1, '8': 1, '7': 1, '2a': 1, '1': 1})
# File  assets/ART_Corpus/ann5/b407371c_mode2.xml
# References to figures...:
# Counter()
# File  assets/ART_Corpus/ann7/b411689e_mode2.xml
# References to figures...:
# Counter({'2a': 5, '1': 5, '5': 2, '4': 2, '3': 2, '3b': 1, '2': 1, '3a': 1, '2b': 1})
# File  assets/ART_Corpus/ann5/b313134c_mode2.xml
# References to figures...:
# Counter({'11': 4, '12': 4, '1': 4, '3': 3, '7': 3, '8': 2, '9': 2, '6': 2, '14': 1, '2': 1, '13': 1, '10': 1})
# File  assets/ART_Corpus/ann9/b506790a_mode2.xml
# References to figures...:
# Counter({'1': 2})

# %% [markdown]
# So now we know which papers have which figures we can find out which paper has the most different figures and which one references figures the most.

# %%
sorted_figs_by_refcount = [ (x, sum( figs[x].values())) for x in 
               sorted(figs, key=lambda x: sum( figs[x].values()), reverse=True ) ] 

sorted_figs_by_variety = [ (x, len(figs[x])) for x in 
               sorted(figs, key=lambda x: len( figs[x] ), reverse=True ) ] 

print("Top 5 papers by number of references to figures (frequency)")
for paper,count in sorted_figs_by_refcount[0:5]:
    print("Title: {} Count: {}".format(paper,count))
print("\n\n")
print("Top 5 papers by number of different figures in paper (variance)")
for paper,count in sorted_figs_by_variety[0:5]:
    print("Title: {} Count: {}".format(paper,count))
# Out:
# Top 5 papers by number of references to figures (frequency)
# Title: assets/ART_Corpus/ann8/b506075c_mode2.xml Count: 48
# Title: assets/ART_Corpus/ann5/b311582h_mode2.xml Count: 45
# Title: assets/ART_Corpus/ann2/b308202d_mode2.xml Count: 39
# Title: assets/ART_Corpus/ann6/b308201f_mode2.xml Count: 37
# Title: assets/ART_Corpus/ann9/b413603a_mode2.xml Count: 37
#
#
#
# Top 5 papers by number of different figures in paper (variance)
# Title: assets/ART_Corpus/ann7/b413535k_mode2.xml Count: 26
# Title: assets/ART_Corpus/ann3/b405531d_mode2.xml Count: 20
# Title: assets/ART_Corpus/ann5/b402623c_mode2.xml Count: 20
# Title: assets/ART_Corpus/ann8/b316895f_mode2.xml Count: 19
# Title: assets/ART_Corpus/ann9/b502789f_mode2.xml Count: 18

# %% [markdown]
# ## Conclusion
#
# We have used regular expressions to parse semi-structured data inside the ART Corpus and determine which of the papers have the most diverse and most frequent references to figures.
#
# Our final chapter looks at [NLTK](NLTK.ipynb)
